# %%
import pandas as pd

# %%
curr_file = pd.read_csv('curriculum_metadata.csv')
curr_file.head()
# Out:
#                       faculty_name_th                        faculty_name_en  \
# 0         คณะสังคมวิทยาและมานุษยวิทยา  Faculty of Sociology and Anthropology
# 1                      คณะเศรษฐศาสตร์                   Faculty of Economics
# 2  คณะสถาปัตยกรรมศาสตร์และการผังเมือง   Faculty of Architecture and Planning
# 3                          ศิลปศาสตร์                                   Arts
# 4         คณะสังคมวิทยาและมานุษยวิทยา  Faculty of Sociology and Anthropology
#
#           curr-id                                        cur-name-th  \
# 0  25400051100369  หลักสูตรสังคมวิทยาและมานุษยวิทยาบัณฑิต สาขาวิช...
# 1  25510051108732        หลักสูตรเศรษฐศาสตรบัณฑิต (หลักสูตรนานาชาติ)
# 2   2509051100496                     หลักสูตรสถาปัตยกรรมภายในบัณฑิต
# 3  25520051102668                            หลักสูตรศิลปศาสตรบัณฑิต
# 4  25510051100351  หลักสูตรสังคมวิทยาและมานุษยวิทยาบัณฑิต สาขาวิช...
#
#                                          cur-name-en  \
# ...

# %%
curr_type_detail = curr_file[['curr-id', 'curr-type']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 curr_type_detail = curr_file[['curr_id', 'curr_type']]
#
# File c:\Users\U s e r\OneDrive\Desktop\DSI324_file\.venv\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\U s e r\OneDrive\Desktop\DSI324_file\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...
